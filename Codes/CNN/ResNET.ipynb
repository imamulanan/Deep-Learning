# %%
import keras
from keras.applications.resnet50 import ResNet50
from keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

# %%
model = ResNet50(weights='imagenet')
# Out:
# ...
# 102967424/102967424 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
img_path = '/content/drive/MyDrive/Colab Notebooks/PreTrained Model/Burger.webp'
img = keras.utils.load_img(img_path, target_size=(224, 224))
x = keras.utils.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# ...
# 35363/35363 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Predicted: [('n07697313', 'cheeseburger', np.float32(0.99512994)), ('n07693725', 'bagel', np.float32(0.0028858418)), ('n07697537', 'hotdog', np.float32(0.00164903))]

# %%
img_path = '/content/drive/MyDrive/Colab Notebooks/PreTrained Model/photo_2025-11-30_23-41-49.jpg'
img = keras.utils.load_img(img_path, target_size=(224, 224))
x = keras.utils.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step
# Predicted: [('n04370456', 'sweatshirt', np.float32(0.8118613)), ('n03763968', 'military_uniform', np.float32(0.0527725)), ('n03141823', 'crutch', np.float32(0.035104714))]

# %%
img_path = '/content/drive/MyDrive/Colab Notebooks/PreTrained Model/Dog.webp'
img = keras.utils.load_img(img_path, target_size=(224, 224))
x = keras.utils.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step
# Predicted: [('n02110958', 'pug', np.float32(0.9637933)), ('n02112706', 'Brabancon_griffon', np.float32(0.0075788577)), ('n02108915', 'French_bulldog', np.float32(0.004427943))]
